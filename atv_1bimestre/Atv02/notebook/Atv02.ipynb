// %% [markdown]
// # Atv02

// %% [markdown]
// Exibir a mensagem “Informe um inteiro: “, deixando o cursor na mesma linha

// %%
System.out.print("Informe um Inteiro: ");
// Out:
// Informe um Inteiro:
// null

// %% [markdown]
// Atribuir o produto das variáveis b e c para a variável a

// %%
import java.util.Scanner;  
Scanner ent = new Scanner(System.in);  

System.out.print("Informe dois números inteiros: ");
int b = ent.nextInt(); int c = ent.nextInt();

int a = (b * c); 

System.out.printf("%d * %d = %d", b, c, a);
// Out:
// Informe dois números inteiros: 30
// 20
// 30 * 20 = 600
// null

// %% [markdown]
// Demonstrar a execução do cálculo e utilizar um comentário para afirmar que é um programa de exemplo de folha de pagamento.

// %%
int b = 30;
int c = 20;

int a = (b*c); //Momento em que a varível "a" recebe o produto de "b" e "c"

System.out.printf("%d * %d = %d", b, c, a);
// Out:
// 30 * 20 = 600
// null
